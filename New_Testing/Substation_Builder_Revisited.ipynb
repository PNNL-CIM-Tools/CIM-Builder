# %% [markdown]
# # Substation Builder Re-visited
#
# This doc revises the automatic substation builder concepts and codes. The objective of ASB was to create an entire substation from scratch using CIM models of its individual components. This was a novel approach because existing methods included creating SS from pre-existing open dss, PSS/E or PSLF models.
#
# Many different types of SS components are built. The different components are:
# 1. Single bus
# 2. Sectionalized bus
# 3. Ring bus
# 4. Breaker and a half
# 5. Double bus single breaker
# 6. Main and transfer
#
# Each of these are explained along with codes next.

# %% [markdown]
# ## Single bus
#
#
# The first part of the code is to load nexxessary libraries and the xml file.

# %%
# Import transmission and distribution modeling classes
from cimgraph.models import FeederModel, NodeBreakerModel
from cimgraph.databases import ConnectionParameters, RDFlibConnection, BlazegraphConnection
import cimgraph.utils as utils

import importlib

# %%
cim_profile = 'cimhub_2023'
cim = importlib.import_module('cimgraph.data_profile.' + cim_profile)

# %%
params = ConnectionParameters(filename=None, cim_profile=cim_profile, iec61970_301=8)
connection = RDFlibConnection(params)

# %%
from cimbuilder.substation_builder import SingleBusSubstation

# %%
SubBuilder = SingleBusSubstation(connection=connection, name="single_sub", base_voltage=115000)
substation = SubBuilder.substation

# %%
# Import 13 bus model from XML file
ieee13_feeder = cim.Feeder(mRID = '49AD8E07-3BF9-A4E2-CB8F-C3722F837B62')
params = ConnectionParameters(filename='../test_models/IEEE13.xml', cim_profile=cim_profile, iec61970_301=8)
connection = RDFlibConnection(params)
ieee13_network = FeederModel(connection=connection, container=ieee13_feeder, distributed=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 params = ConnectionParameters(filename='../test_models/IEEE13.xml', cim_profile=cim_profile, iec61970_301=8)
#       4 connection = RDFlibConnection(params)
# ----> 5 ieee13_network = FeederModel(connection=connection, container=ieee13_feeder, distributed=False)
#
# File <string>:9, in __init__(self, container, connection, distributed, graph, topology_message, distributed_hierarchy)
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/cimgraph/models/feeder_model.py:48, in FeederModel.__post_init__(self)
#      45         self.initialize_distributed_model(self.container)
#      46     else:
#      47         # Otherwise build centralized network model
# ---> 48         self.initialize_centralized_model(self.container)
#      49 else:    # Log error thant no connection was specified
#      50     _log.error('A ConnectionInterface must be specified')
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/cimgraph/models/feeder_model.py:54, in FeederModel.initialize_centralized_model(self, container)
#      52 def initialize_centralized_model(self, container: object) -> None:
#      53     # Build graph model using database-specific routine
# ---> 54     self.graph = self.connection.create_new_graph(container)
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/cimgraph/databases/rdflib/rdflib.py:64, in RDFlibConnection.create_new_graph(self, container)
#      62 # Get all nodes, terminal, and equipment by
#      63 sparql_message = sparql.get_all_nodes_sparql(container, self.namespace)
# ---> 64 query_output = self.execute(sparql_message)
#      66 for result in query_output:
#      67     # Parse query results
#      68     node_mrid = str(result.ConnectivityNode)
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/cimgraph/databases/rdflib/rdflib.py:56, in RDFlibConnection.execute(self, query_message)
#      55 def execute(self, query_message: str) -> QueryResponse:
# ---> 56     self.connect()
#      57     query_output = self.libgraph.query(query_message)
#      58     return query_output
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/cimgraph/databases/rdflib/rdflib.py:48, in RDFlibConnection.connect(self)
#      45 else:
#      46     self.libgraph = Graph()
# ---> 48 self.libgraph.parse(self.filename)
#      49 self.libgraph.bind('cim', Namespace(self.namespace))
#      50 self.libgraph.bind('rdf', RDF)
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/rdflib/graph.py:1468, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1373 def parse(
#    1374     self,
#    1375     source: Optional[
#    (...)
#    1383     **args: Any,
#    1384 ) -> "Graph":
#    1385     """
#    1386     Parse an RDF source adding the resulting triples to the Graph.
#    1387
#    (...)
#    1465
#    1466     """
# -> 1468     source = create_input_source(
#    1469         source=source,
#    1470         publicID=publicID,
#    1471         location=location,
#    1472         file=file,
#    1473         data=data,
#    1474         format=format,
#    1475     )
#    1476     if format is None:
#    1477         format = source.content_type
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/rdflib/parser.py:401, in create_input_source(source, publicID, location, file, data, format)
#     394         assert data is None
#     395         assert source is None
#     396     (
#     397         absolute_location,
#     398         auto_close,
#     399         file,
#     400         input_source,
# --> 401     ) = _create_input_source_from_location(
#     402         file=file,
#     403         format=format,
#     404         input_source=input_source,
#     405         location=location,
#     406     )
#     408 if file is not None:
#     409     if TYPE_CHECKING:
#
# File ~/CIM-Builder/.venv/lib/python3.10/site-packages/rdflib/parser.py:461, in _create_input_source_from_location(file, format, input_source, location)
#     459 if absolute_location.startswith("file:///"):
#     460     filename = url2pathname(absolute_location.replace("file:///", "/"))
# --> 461     file = open(filename, "rb")
#     462 else:
#     463     input_source = URLInputSource(absolute_location, format)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/test_models/IEEE13.xml'
