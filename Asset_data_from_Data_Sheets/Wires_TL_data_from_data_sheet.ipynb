# %% [markdown]
# The asset parameters from capacitor dat sheets of various OEMs are collected and saved here

# %% [markdown]
# Resource 1: Capacior data from Eaton manual - "https://www.eaton.com/content/dam/eaton/products/medium-voltage-power-distribution-control-systems/power-capacitors/pole-mounted-capacitor-racks-with-single-phase-capacitor-units-catalog-ca230001en.pdf"

# %% [markdown]
# Ressource 2 - GE capacitors: https://www.gevernova.com/grid-solutions/sites/default/files/resources/products/brochures/hvcapacitors-applicationguide-en-32044a-ltr-2018-04-r001_lr.pdf
