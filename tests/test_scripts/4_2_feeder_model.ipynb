# %% [markdown]
# # Distribution Feeder Modeling

# %% [markdown]
# This section contains description of distribution feeder modeling concepts and usage of the CIMantic Graphs `FeederModel` class for accessing CIM feeder models in a centralized and distributed manner.
#
# All diagrams within this page have been auto-generated using mermaid.js and the `cimgraph.utils` module of CIMantic Graphs, which can be imported using

# %%
# !pip list
from cimgraph import utils
from mermaid import Mermaid
# Out:
# Package                   Version      Editable project location
# ------------------------- ------------ -------------------------------------------------------------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# build                     1.4.0
# CacheControl              0.14.4
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# cim-builder               0.0.1a0      C:\Users\mitr284\OneDrive - PNNL\Documents\GitHub\CIM-Builder
# cim-graph                 0.4.3a8
# cleo                      2.1.0
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# crashtest                 0.4.1
# cycler                    0.12.1
# dateutils                 0.6.12
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# distlib                   0.4.0
# docopt                    0.6.2
# dulwich                   1.1.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.25.0
# findpython                0.7.1
# flexcache                 0.3
# flexparser                0.4
# fonttools                 4.61.1
# fqdn                      1.5.1
# gridappsd-python          2026.2.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# installer                 0.7.0
# ipykernel                 7.2.0
# ipython                   9.10.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# jaraco.classes            3.4.0
# jaraco.context            6.1.0
# jaraco.functools          4.4.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.8.0
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# keyring                   25.7.0
# kiwisolver                1.4.9
# lark                      1.3.1
# loguru                    0.7.3
# MarkupSafe                3.0.3
# matplotlib                3.10.8
# matplotlib-inline         0.2.1
# mermaid-python            0.1
# mistune                   3.2.0
# more-itertools            10.8.0
# msgpack                   1.1.2
# mysql-connector-python    9.6.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# neo4j                     5.28.3
# nest-asyncio              1.6.0
# notebook                  7.5.4
# notebook_shim             0.2.4
# numpy                     2.4.0
# oxrdflib                  0.3.7
# packaging                 25.0
# pandas                    2.3.3
# pandocfilters             1.5.1
# parso                     0.8.6
# pbs-installer             2026.2.11
# pillow                    12.1.0
# Pint                      0.24.4
# pip                       26.0.1
# pkginfo                   1.12.1.2
# platformdirs              4.9.2
# poetry                    2.3.2
# poetry-core               2.3.1
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# psutil                    7.2.2
# pure_eval                 0.2.3
# pycparser                 3.0
# Pygments                  2.19.2
# pyoxigraph                0.3.22
# pyparsing                 3.3.1
# pyproject_hooks           1.2.0
# python-dateutil           2.9.0.post0
# python-discovery          1.1.0
# python-dotenv             1.2.2
# python-json-logger        4.0.0
# pytz                      2025.2
# pywin32-ctypes            0.2.3
# pywinpty                  3.0.3
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# RapidFuzz                 3.14.3
# rdflib                    7.6.0
# referencing               0.37.0
# requests                  2.32.5
# requests-toolbelt         1.0.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# seaborn                   0.13.2
# Send2Trash                2.1.0
# setuptools                82.0.0
# shellingham               1.5.4
# six                       1.17.0
# soupsieve                 2.8.3
# SPARQLWrapper             2.0.0
# stack-data                0.6.3
# stomp.py                  6.0.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomlkit                   0.14.0
# tornado                   6.5.4
# traitlets                 5.14.3
# trove-classifiers         2026.1.14.14
# typing_extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# virtualenv                21.1.0
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# widgetsnbextension        4.0.15
# win32_setctime            1.2.0
# zstandard                 0.25.0

# %% [markdown]
# ## Distribution Feeders in CIM
#
# Full modeling of North American distribution circuits was introduced in CIM 17 to include include unbalanced medium-voltage networks, low-voltage customer-side equipment, DERs, and advanced metering infrastructure (AMI) usage points. An example of a very simple distribution feeder is shown and explained in detail below:
#
# ![basic-feeder](./images/4_2_feeder.png)

# %% [markdown]
# * `ConnectivityNode` used for 3-phase buses. Separate modeling of single-phase nodes not used
#
# * `Terminal` used to connect conducting equipment to a bus
#
# * `ACLineSegment` used for overhead lines, underground cables, and secondary triplex lines. Phasing represented using `ACLineSegmentPhase`
#
# * Representation of downstream switching devices using `Recloser`, `Sectionaliser`, etc.
# Poletop `LinearShuntCompensator` and `RatioTapChanger` devices
#
# * `EnergySource` slack bus at substation
#
# * Loads can be represented at medium voltage level or broken down into individual `EnergyConsumer` customers with split-phase `TransformerTank`

# %% [markdown]
# ----

# %% [markdown]
# ## FeederModel Class
#
# The `FeederModel` class in CIMantic Graphs provides the interface for users to access a single feeder at a time (in a manner similar to study tools such as EPRI OpenDSS or Eaton CYME). The class provides access to the typed property graph and API methods to read and write to a data source.
#
# It can be imported using

# %%
from cimgraph.models import FeederModel

# %% [markdown]
# The structure of the distribution network graphs and API methods are explained in the sections below

# %% [markdown]
# ----

# %% [markdown]
# ## Loading a FeederModel from an XML File
#
# When working with small test cases (e.g. IEEE 13 and 123 bus models), it is possible to use CIMantic Graphs without any database and instead directly build the graph from an XML file. *Note: large models (e.g. IEEE 8500) will see poor performance when reading directly from the XML (approx 2 minutes to load all triples and build the full network graph).*

# %% [markdown]
# The first step is to import the correct CIM profile to use and set the associated environment variable used by CIM-Graph. For an explanation of CIM profiles, see [Profiles Overview](../02_cim_profiles/2_1_profiles_overview.ipynb)

# %%
import os
os.environ['CIMG_CIM_PROFILE'] = 'cim17v40'
import cimgraph.data_profile.cim17v40 as cim

# %% [markdown]
# Next, use the `XMLFile` interface to open the XML file:

# %%
from cimgraph.databases import XMLFile
file = XMLFile(filename='../../tests/test_models/IEEE13.xml')
os.environ['CIMG_VALIDATION_LOG_LEVEL'] = 'DEBUG'

# %% [markdown]
# Finally, create a new `FeederModel` network class to load the feeder into the graph:

# %%
network = FeederModel(container=cim.Feeder(), connection=file)
os.environ['CIMG_VALIDATION_LOG_LEVEL'] = 'DEBUG'

# %% [markdown]
# The complete network model, including both forward and reverse associations between all objects in the model has now been loaded into the FeederModel graph.
#
# To demonstrate the structure of resulting FeederModel network, we can display a sample  breaker object:

# %%
# Get first breaker in graph
breaker = network.first(cim.SynchronousMachine)
# Display the line
Mermaid(utils.get_mermaid(breaker))
# Out:
#         <div class="mermaid-207a02f4-19f2-48f5-9586-abfcb0732835"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '';
#             const element = document.querySelector('.mermaid-207a02f4-19f2-48f5-9586-abfcb0732835');
#             const { svg } = await mermaid.render('graphDiv-207a02f4-19f2-48f5-9586-abfcb0732835', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %%
print(dir(cim))
# Out:
# ['ACDCConverter', 'ACDCConverterDCTerminal', 'ACDCTerminal', 'ACLineSegment', 'ACLineSegmentPhase', 'ASTMStandard', 'AcceptanceTest', 'AccountNotification', 'AccountingUnit', 'AccumulationKind', 'Accumulator', 'AccumulatorLimit', 'AccumulatorLimitSet', 'AccumulatorReset', 'AccumulatorValue', 'AceTariffType', 'ActivePower', 'ActivePowerChangeRate', 'ActivePowerLimit', 'ActivePowerPerCurrentFlow', 'ActivePowerPerFrequency', 'ActivityRecord', 'AdjacentCASet', 'AggregateKind', 'AggregateNode', 'AggregateScore', 'AggregatedPnode', 'Agreement', 'AirCompressor', 'AlertTypeList', 'AllocationResult', 'AllocationResultValues', 'AltGeneratingUnitMeas', 'AltTieMeas', 'AmiBillingReadyKind', 'Analog', 'AnalogControl', 'AnalogLimit', 'AnalogLimitSet', 'AnalogValue', 'Analytic', 'AnalyticKind', 'AnalyticScore', 'AnchorKind', 'AngleDegrees', 'AngleRadians', 'AnnotatedProjectDependency', 'AnodeType', 'ApnodeType', 'ApparentPower', 'ApparentPowerLimit', 'ApplicationSecurityKind', 'Appointment', 'Approver', 'AreaControlMode', 'AreaKind', 'AreaLoadCurve', 'AreaReserveSpec', 'Asset', 'AssetAnalog', 'AssetContainer', 'AssetDeployment', 'AssetDiscrete', 'AssetFailureClassification', 'AssetFailureMode', 'AssetFunction', 'AssetGroup', 'AssetGroupKind', 'AssetHazardKind', 'AssetHealthEvent', 'AssetInfo', 'AssetKind', 'AssetLifecycleStateKind', 'AssetLocationHazard', 'AssetModelCatalogue', 'AssetModelCatalogueItem', 'AssetModelUsageKind', 'AssetOrganisationRole', 'AssetOwner', 'AssetPropertyCurve', 'AssetStringKind', 'AssetStringMeasurement', 'AssetTestLab', 'AssetTestSampleTaker', 'AssetUser', 'AsynchronousMachine', 'AsynchronousMachineDynamics', 'AsynchronousMachineKind', 'AtmosphericAnalog', 'AtmosphericAnalogKind', 'AtmosphericPhenomenon', 'AttributeInstanceComponent', 'AttributeProperty', 'Auction', 'Author', 'AutomaticDispInstTypeCommitment', 'AuxiliaryAccount', 'AuxiliaryAgreement', 'AuxiliaryCost', 'AuxiliaryEquipment', 'AuxiliaryObject', 'AuxiliaryValues', 'BWRSteamSupply', 'BankAccount', 'BaseFrequency', 'BasePower', 'BaseReading', 'BaseVoltage', 'BaseWork', 'BasicIntervalSchedule', 'BatteryStateKind', 'BatteryUnit', 'Bay', 'Bearing', 'Bid', 'BidDistributionFactor', 'BidSelfSched', 'BidTimeSeries', 'BidType', 'BidTypeRMR', 'BilateralExchangeActor', 'BilateralExchangeAgreement', 'BillDeterminant', 'BillMediaKind', 'BoilerControlMode', 'BranchEndFlow', 'BranchGroup', 'BranchGroupTerminal', 'Breaker', 'BreakerApplicationKind', 'BreakerConfiguration', 'BreakerFailureReasonKind', 'BusNameMarker', 'BusbarConfiguration', 'BusbarSection', 'BusbarSectionInfo', 'Bushing', 'BushingInfo', 'BushingInsulationKind', 'BushingInsulationPF', 'BushingInsulationPfTestKind', 'BusinessCase', 'CAESPlant', 'CIGREStandard', 'CRRMarket', 'CSCDynamics', 'CTTempActivePowerCurve', 'Cabinet', 'CableConstructionKind', 'CableInfo', 'CableOuterJacketKind', 'CableShieldMaterialKind', 'CalculationIntervalUnitKind', 'CalculationKind', 'CalculationMethodHierarchy', 'CalculationMethodOrder', 'CalculationModeKind', 'CalculationTechniqueKind', 'Capacitance', 'CapacitancePerLength', 'CashierShift', 'CatalogAssetType', 'ChangeSet', 'ChangeSetMember', 'Channel', 'Charge', 'ChargeComponent', 'ChargeGroup', 'ChargeKind', 'ChargeType', 'Circuit', 'Clamp', 'ClampAction', 'Classification', 'ClassificationCondition', 'ClearanceAction', 'ClearanceActionKind', 'ClearanceDocument', 'CloudCondition', 'CloudKind', 'CnodeDistributionFactor', 'CogenerationPlant', 'ComDirectionKind', 'ComFunction', 'ComModule', 'ComTechnologyKind', 'CombinedCyclePlant', 'CombustionTurbine', 'Command', 'CommodityDefinition', 'CommodityKind', 'CommodityPrice', 'CommunicationLink', 'CompatibleUnit', 'CompositeSwitch', 'ConcentricNeutralCableInfo', 'ConditionFactor', 'ConditionFactorKind', 'Conductance', 'ConductancePerLength', 'ConductingEquipment', 'Conductor', 'ConfigurationEvent', 'ConformLoad', 'ConformLoadGroup', 'ConformLoadSchedule', 'CongestionArea', 'CongestionRevenueRight', 'ConnectDisconnectFunction', 'Connec ...

# %%
pv = network.first(cim.PhotoVoltaicUnit)
Mermaid(utils.get_mermaid(cim.PowerTransformer))
# Out:
#         <div class="mermaid-cbea3263-5da5-4b63-915e-9f8b84765502"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class PowerTransformer{\n        <<informative>>\n        + isPartOfGeneratorUnit: bool\n        + operationalValuesConsidered: bool\n        + vectorGroup: str\n        + beforeShCircuitHighestOperatingCurrent: float | CurrentFlow\n        + beforeShCircuitHighestOperatingVoltage: float | Voltage\n        + beforeShortCircuitAnglePf: float | AngleDegrees\n        + highSideMinOperatingU: float | Voltage\n    }\n    ConductingEquipment <|-- PowerTransformer : inherits from\n    PowerTransformer --> "0..*" PowerTransformerEnd : PowerTransformerEnd \n    PowerTransformer --> "0..*" TransformerTank : TransformerTanks \n';
#             const element = document.querySelector('.mermaid-cbea3263-5da5-4b63-915e-9f8b84765502');
#             const { svg } = await mermaid.render('graphDiv-cbea3263-5da5-4b63-915e-9f8b84765502', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ----

# %% [markdown]
# ## Loading a FeederModel from a Database
#
# When working with large models (e.g. IEEE 8500/9500 node or utility networks), it is generally advisable to load the the models into a database and then use CIM-Graph to access the feeder via its internal API.

# %% [markdown]
# The first step is to import the correct CIM profile to use and set the associated environment variable used by CIM-Graph. For an explanation of CIM profiles, see [Profiles Overview](../02_cim_profiles/2_1_profiles_overview.ipynb).

# %%
import os
os.environ['CIMG_CIM_PROFILE'] = 'cimhub_2023'
import cimgraph.data_profile.cimhub_2023 as cim

# %% [markdown]
# Next, use the interface class to your preferred database to authenticate and connect to the database.

# %%
from cimgraph.databases import BlazegraphConnection
os.environ['CIMG_URL'] = 'http://localhost:8889/bigdata/namespace/kb/sparql'
database = BlazegraphConnection()

# %% [markdown]
# Next, create a CIM `Feeder` object with the correct model mRID. This can be done by a) directly creating the object or b) retrieving it from the database using the `.get_object()` method.

# %%
feeder = cim.Feeder(mRID="49AD8E07-3BF9-A4E2-CB8F-C3722F837B62")
print(feeder)
# Out:
# {"@id": "49ad8e07-3bf9-a4e2-cb8f-c3722f837b62", "@type": "Feeder"}

# %%
feeder = database.get_object(mRID="49ad8e07-3bf9-a4e2-cb8f-c3722f837b62")
print(feeder)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:942, in HTTPConnection.connect(self)
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\socket.py:857, in create_connection(address, timeout, source_address)
#     856 try:
# --> 857     raise err
#     858 finally:
#     859     # Break explicitly a reference cycle
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 feeder = database.get_object(mRID="49ad8e07-3bf9-a4e2-cb8f-c3722f837b62")
#       2 print(feeder)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\databases\blazegraph\blazegraph.py:105, in BlazegraphConnection.get_object(self, mRID, graph)
#     103 sparql_message = sparql.get_object_sparql(mRID)
#     104 # Execute query
# --> 105 query_output = self.execute(sparql_message)
#     106 obj = None
#     107 # Parse query results to get the correct CIM object
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\databases\blazegraph\blazegraph.py:66, in BlazegraphConnection.execute(self, query_message)
#      64 self.sparql_obj.setQuery(query_message)
#      65 self.sparql_obj.setMethod(POST)
# ---> 66 query_output = self.sparql_obj.query().convert()
#      67 return query_output
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10061] No connection could be made because the target machine actively refused it>

# %% [markdown]
# Finally, create a new `FeederModel` class and pass in the feeder and database objects as the input arguments. This will authenticate with the database and load the base feeder topology into the graph

# %%
network = FeederModel(container=feeder, connection=database)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\http\client.py:942, in HTTPConnection.connect(self)
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\socket.py:857, in create_connection(address, timeout, source_address)
#     856 try:
# --> 857     raise err
#     858 finally:
#     859     # Break explicitly a reference cycle
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 network = FeederModel(container=feeder, connection=database)
#
# File <string>:11, in __init__(self, container, connection, distributed, graph, incrementals, __class_iter__, topology_message, distributed_areas)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\models\feeder_model.py:54, in FeederModel.__post_init__(self)
#      51         self.__initialize_distributed_model()
#      52     else:
#      53         # Otherwise build centralized network model
# ---> 54         self.__initialize_centralized_model()
#      55 else:    # Log error thant no connection was specified
#      56     _log.error('A ConnectionInterface must be specified')
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\models\feeder_model.py:62, in FeederModel.__initialize_centralized_model(self)
#      60 def __initialize_centralized_model(self) -> None:
#      61     # Build graph model using database-specific routine
# ---> 62     self.graph = self.connection.create_new_graph(self.container, self.graph)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\databases\blazegraph\blazegraph.py:169, in BlazegraphConnection.create_new_graph(self, container, graph)
#     167 # Get all nodes, terminal, and equipment associated with EquipmentContainer object
#     168 sparql_message = sparql.get_all_nodes_from_container(container)
# --> 169 query_output = self.execute(sparql_message)
#     170 # Parse query results and create new graph
#     171 graph = self.parse_node_query(graph, query_output)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\cimgraph\databases\blazegraph\blazegraph.py:66, in BlazegraphConnection.execute(self, query_message)
#      64 self.sparql_obj.setQuery(query_message)
#      65 self.sparql_obj.setMethod(POST)
# ---> 66 query_output = self.sparql_obj.query().convert()
#      67 return query_output
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File ~\AppData\Local\anaconda3\envs\cimemt\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10061] No connection could be made because the target machine actively refused it>

# %% [markdown]
# To ensure performance on large models, only the minimum set of `Equipment`, `ConnectivityNode`, and `Terminal` objects are loaded into graph with only their UUID identifiers. All attributes are left as `None` or `[]` until the object classes are populated using the `.get_all_edges` method.

# %%
# Get first breaker in graph
breaker = network.first(cim.Breaker)
# Display the breaker
Mermaid(utils.get_mermaid(breaker))
# Out:
#         <div class="mermaid-cda298ea-2157-4463-bb99-bc1dc5754889"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = 'mindmap\n    52DE9189((**Breaker**\n        name: brkr1\n        normalOpen: False\n        open: False\n        retained: True\n        ratedCurrent: 400.0\n        breakingCapacity: 400.0))\n        [Location]\n            085BBE1F(**Location**\n                name: brkr1_Loc)\n        [EquipmentContainer]\n            49AD8E07(**Feeder**\n                name: ieee13nodeckt)\n        [BaseVoltage]\n            2A158E0C(**BaseVoltage**\n                name: BaseV_4.1600)\n        ["Terminals"]\n            1D81C7FE(**Terminal**\n                name: brkr1_T1)\n            2847E06B(**Terminal**\n                name: brkr1_T2)\n';
#             const element = document.querySelector('.mermaid-cda298ea-2157-4463-bb99-bc1dc5754889');
#             const { svg } = await mermaid.render('graphDiv-cda298ea-2157-4463-bb99-bc1dc5754889', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ----

# %% [markdown]
# ## FeederModel.graph
#
# The `.graph` attribute of the GraphModel dataclass provides the interface to the typed property graph with all data contained in the network model.
#
# It is a dictionary typed first by class type (e.g. `cim.ACLineSegment`) and then by UUID of each element within the network model.
#
# All objects within the graph (if added using the API) are forced to have a unique UUID identifier.

# %% [markdown]
# ### Graph Initialization
#
# The CIM `Feeder` class is used to describe containment and naming of equipment and nodes within distribution feeders. For most applications, each feeder is described as having a single normal energizing substation that serves as the source for all downstream customers.

# %%
diagram_text = utils.get_mermaid_path(cim.Feeder, "Equipments", show_attributes=False)
diagram_text = utils.add_mermaid_path(cim.Feeder, "ConnectivityNodes", diagram_text, show_attributes=False)
diagram_text = utils.add_mermaid_path(cim.Feeder, "NormalEnergizingSubstation", diagram_text, show_attributes=False)
diagram_text = utils.add_mermaid_path(cim.Equipment, "Measurements", diagram_text, show_attributes=False)
diagram_text = utils.add_mermaid_path(cim.ConnectivityNode, "Terminals", diagram_text, show_attributes=False)

Mermaid(diagram_text)
# Out:
#         <div class="mermaid-fe8e10c5-8c0f-4bc5-9610-368184795b16"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class Feeder{\n        <<Concrete>>\n    }\n    class Equipment{\n        <<OfAggregate>>\n    }\n    Feeder --> "0..*" ConnectivityNode : ConnectivityNodes \n    class ConnectivityNode{\n        <<Concrete>>\n    }\n    class Substation{\n        <<Concrete>>\n    }\n    class Measurement{\n    }\n    ConnectivityNode --> "0..*" Terminal : Terminals \n    class Terminal{\n    }\n';
#             const element = document.querySelector('.mermaid-fe8e10c5-8c0f-4bc5-9610-368184795b16');
#             const { svg } = await mermaid.render('graphDiv-fe8e10c5-8c0f-4bc5-9610-368184795b16', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %% [markdown]
# ----

# %% [markdown]
# ### Graph Expansion
#
# One of the key features of CIMantic graphs is the elimination of all custom database queries to access information regarding equipment, impedances, measurements etc. Instead, a single API method is used to extract all information about the
#
# The `.get_all_edges()` method is the core library method that enables the flexibility of CIM-Graph to query for CIM objects of any class and build the knowledge graph without custom queries.
#
# The arguments of the method are
#
# * cim_class (type): The CIM class for which to retrieve edges (e.g. `cim.Breaker`)

# %%
network.get_all_edges(cim.Breaker)

# %%
# Display the same breaker
Mermaid(utils.get_mermaid(breaker))
# Out:
#         <div class="mermaid-3f390376-dd22-45b8-adf7-314e11157fee"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = 'mindmap\n    52de9189((**Breaker**\n        name: brkr1\n        normalOpen: False\n        open: False\n        retained: True\n        ratedCurrent: 400.0\n        breakingCapacity: 400.0))\n        [Location]\n            085bbe1f(**Location**\n                name: None)\n        ["Measurements"]\n            8b230dfe(**Analog**\n                name: None)\n            93b441c7(**Analog**\n                name: None)\n            9a379d4c(**Analog**\n                name: None)\n            db91a191(**Discrete**\n                name: None)\n            ef2fa8e2(**Discrete**\n                name: None)\n            3e7ee924(**Discrete**\n                name: None)\n        [EquipmentContainer]\n            49AD8E07(**Feeder**\n                name: None)\n        [SubSchedulingArea]\n            b6373777(**FeederArea**\n                name: None)\n        [BaseVoltage]\n            2a158e0c(**BaseVoltage**\n                name: None)\n        ["Terminals"]\n            1d81c7fe(**Terminal**\n                name: None)\n            2847e06b(**Terminal**\n                name: None)\n';
#             const element = document.querySelector('.mermaid-3f390376-dd22-45b8-adf7-314e11157fee');
#             const { svg } = await mermaid.render('graphDiv-3f390376-dd22-45b8-adf7-314e11157fee', graphDefinition);
#             element.innerHTML = svg;
#         </script>
